# %%
import os
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms
import numpy as np
import cv2

# %%
class transformerNet(nn.Module):
    def __init__(self):
        super().__init__()
        self.net = nn.Sequential(
            # work in progress
        )
        
    def forward(self,x):
        x = self.net(x)
        return x

def train(model, loader, optimizer, l):
    print('training')
    model.train()
    for videos, labels in loader:
        optimizer.zero_grad()
        outputs = model(videos)
        loss = l(outputs, labels)
        print('loss', loss)
        l.backward()
        optimizer.step()


def evaluate(model, loader, l):
    model.eval()
    correct = 0
    total = 0
    with torch.no_grad():
        for videos, labels in loader:
            outputs = model(videos)
            loss = l(outputs, labels)
            _, predicted = outputs.max(1)
            total += labels.size(0)
            correct += predicted.eq(labels).sum().item()

# %%
from dataset import UCFdataset

frame_transform = transforms.Compose([
    transforms.ToPILImage(),
    transforms.Resize(128),
    transforms.CenterCrop(112),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])


class_index_file = '/Users/sanjitk./team-2/UTD-team-2/ucfTrainTestlist/classInd.txt'
train_split = '/Users/sanjitk./team-2/UTD-team-2/ucfTrainTestlist/trainlist01.txt'
test_split = '/Users/sanjitk./team-2/UTD-team-2/ucfTrainTestlist/testlist01.txt'


train_dataset = UCFdataset(class_index_file, train_split, transform=frame_transform)
test_dataset = UCFdataset(class_index_file, train_split, transform=frame_transform)
train_loader = DataLoader(train_dataset, batch_size=2, shuffle=True, num_workers=1)
test_loader = DataLoader(test_dataset, batch_size=2, shuffle=False, num_workers=1)

model = transformerNet()
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=1e-3)
best = 0


print('starting')

for epoch in range(5):
    train_loss, train_acc = train(model, train_loader, criterion, optimizer)
    test_loss, test_acc = evaluate(model, test_loader, criterion)
    print('on epoch', epoch)
    if test_acc > best_acc:
            best_acc = test_acc
